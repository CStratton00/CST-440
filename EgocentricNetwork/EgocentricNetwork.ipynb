# %% [markdown]
# # Egocentric Networks
# ### Dharma Teja Bhattu and Collin Stratton
# ### CST-440
# ### Isac Artzi
# ### 1/31/2022
#
# ## Introduction
#
# For this project, we collected data about Collins Github followers. We had some troubles directly connecting to Github's API, so we manually created the dataset. We noted all of Collin's followers and chose a few of them to see who they are following. We first plotted the network to see how everyone was connected. After that, we found the centrality used to find the most influential person in the dataset.
#
# ## Implementation Process
# Our original idea for this project was to use data about music artists to see who worked with whom. We found a few datasets on Kaggle, but we decided not to follow up on that. Collin briefly looked into using the NBA player dataset, but we decided we did not want to proceed. After further discussion, we planned to use Twitter API to capture all the followers in Dharma's account. However, we had several issues connecting to the API, and there were also limitations to using the free developer account. There were also not many followers to search through, which would have hampered us later. We realized we would have this problem even with other APIs, so we used Justin Fernald's dataset as a reference and manually made our dataset. We took Collin's followers on GitHub and searched through them to see who they follow. In order to build the network, we looked into several different websites and ended up following a YouTube video (linked below) to help us guide and build this network.

# %%
# libraries
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# get the csv and prints it
df = pd.read_csv("Github_following.csv")
df.head()
# Out:
#             v1           v2  v3
# 0  CStratton00    RCarson10   0
# 1  CStratton00    dharmab31   0
# 2  CStratton00       mxmnci   0
# 3  CStratton00     pnghi320   0
# 4  CStratton00  AHarriss155   0

# %%
# create a followers graph and show the edges
followers_graph = nx.from_pandas_edgelist(df, source="v1", target="v2")
followers_graph.edges()
# Out:
# EdgeView([('CStratton00', 'RCarson10'), ('CStratton00', 'dharmab31'), ('CStratton00', 'mxmnci'), ('CStratton00', 'pnghi320'), ('CStratton00', 'AHarriss155'), ('CStratton00', 'brandondavid714'), ('CStratton00', 'James-Fritz'), ('CStratton00', 'Kevin-Wooden'), ('CStratton00', 'rhawks00'), ('CStratton00', 'Austin-Chandler'), ('CStratton00', 'KyleLuster'), ('CStratton00', 'jcanode'), ('CStratton00', 'thedinosoar'), ('CStratton00', 'justinfernald'), ('CStratton00', 'ReuelAbi'), ('CStratton00', 'MicahWillis'), ('CStratton00', 'JakeHafele101'), ('CStratton00', 'drewesch'), ('CStratton00', 'carsonbfoley'), ('CStratton00', 'Iroe7'), ('CStratton00', 'Jsamyn'), ('RCarson10', 'James-Fritz'), ('RCarson10', 'justinfernald'), ('RCarson10', 'jcanode'), ('RCarson10', 'thedinosoar'), ('RCarson10', 'AHarriss155'), ('RCarson10', 'LydiaFritz'), ('RCarson10', 'pnghi320'), ('mxmnci', 'hritikb27'), ('mxmnci', 'torvalds'), ('mxmnci', 'mguay22'), ('mxmnci', 'codediodeio'), ('mxmnci', 'streamich'), ('mxmnci', 
# ...

# %%
# plot the graph
nx.draw(followers_graph,with_labels = True)

# %%
# find the centrality of the graph
nx.degree(followers_graph)
# Out:
# DegreeView({'CStratton00': 21, 'RCarson10': 8, 'dharmab31': 1, 'mxmnci': 21, 'pnghi320': 8, 'AHarriss155': 16, 'brandondavid714': 1, 'James-Fritz': 9, 'Kevin-Wooden': 1, 'rhawks00': 1, 'Austin-Chandler': 1, 'KyleLuster': 1, 'jcanode': 11, 'thedinosoar': 9, 'justinfernald': 6, 'ReuelAbi': 1, 'MicahWillis': 1, 'JakeHafele101': 1, 'drewesch': 1, 'carsonbfoley': 1, 'Iroe7': 1, 'Jsamyn': 6, 'LydiaFritz': 2, 'hritikb27': 1, 'torvalds': 1, 'mguay22': 1, 'codediodeio': 1, 'streamich': 1, 'bfan1256': 1, 'EmersonDove': 1, 'metachris': 1, 'mattgperry': 1, 'Chalarangelo': 1, 'trekhleb': 1, 'isaacs': 1, 'kentcdodds': 1, 'jossmac': 1, 'crubier': 1, 'mxstbr': 1, 'sct': 1, 'Dulaya': 1, 'geohot': 1, 'timgrossmann': 1, 'noahr1936': 2, 'Espence308': 3, 'jakewhitebread': 1, 'natsukiabe529': 1, 'malikbawa': 1, 'Luis-1337': 1, 'isac-artzi': 2, 'ksharma2606': 1, 'ljw1004': 1, 'robtarr': 1, 'jarheadwerm': 1, 'gcustone': 1, 'aviviano': 1, 'BerkanYildiz': 1, 'wilgarrett610': 1})

# %%
# find the most influential people visually
plt.figure(figsize=(25,25))
nx.draw_networkx(followers_graph)
plt.show()

# %%
# degree of centrality
nx.degree_centrality(followers_graph)
# Out:
# {'CStratton00': 0.3684210526315789,
#  'RCarson10': 0.14035087719298245,
#  'dharmab31': 0.017543859649122806,
#  'mxmnci': 0.3684210526315789,
#  'pnghi320': 0.14035087719298245,
#  'AHarriss155': 0.2807017543859649,
#  'brandondavid714': 0.017543859649122806,
#  'James-Fritz': 0.15789473684210525,
#  'Kevin-Wooden': 0.017543859649122806,
#  'rhawks00': 0.017543859649122806,
#  'Austin-Chandler': 0.017543859649122806,
#  'KyleLuster': 0.017543859649122806,
#  'jcanode': 0.19298245614035087,
#  'thedinosoar': 0.15789473684210525,
#  'justinfernald': 0.10526315789473684,
#  'ReuelAbi': 0.017543859649122806,
#  'MicahWillis': 0.017543859649122806,
#  'JakeHafele101': 0.017543859649122806,
#  'drewesch': 0.017543859649122806,
#  'carsonbfoley': 0.017543859649122806,
#  'Iroe7': 0.017543859649122806,
#  'Jsamyn': 0.10526315789473684,
#  'LydiaFritz': 0.03508771929824561,
#  'hritikb27': 0.017543859649122806,
#  'torvalds': 0.017543859649122806,
#  'mguay22': 0.017543859649122806,
# ...

# %%
# find the most influential person in the data set
most_influential = nx.degree_centrality(followers_graph)
for w in sorted(most_influential, key = most_influential.get, reverse = True):
        print(w, most_influential[w])
# Out:
# CStratton00 0.3684210526315789
# mxmnci 0.3684210526315789
# AHarriss155 0.2807017543859649
# jcanode 0.19298245614035087
# James-Fritz 0.15789473684210525
# thedinosoar 0.15789473684210525
# RCarson10 0.14035087719298245
# pnghi320 0.14035087719298245
# justinfernald 0.10526315789473684
# Jsamyn 0.10526315789473684
# Espence308 0.05263157894736842
# LydiaFritz 0.03508771929824561
# noahr1936 0.03508771929824561
# isac-artzi 0.03508771929824561
# dharmab31 0.017543859649122806
# brandondavid714 0.017543859649122806
# Kevin-Wooden 0.017543859649122806
# rhawks00 0.017543859649122806
# Austin-Chandler 0.017543859649122806
# KyleLuster 0.017543859649122806
# ReuelAbi 0.017543859649122806
# MicahWillis 0.017543859649122806
# JakeHafele101 0.017543859649122806
# drewesch 0.017543859649122806
# carsonbfoley 0.017543859649122806
# Iroe7 0.017543859649122806
# hritikb27 0.017543859649122806
# torvalds 0.017543859649122806
# mguay22 0.017543859649122806
# codediodeio 0.017543859649122806
# ...

# %%
# find the most important connections
most_important_link = nx.eigenvector_centrality(followers_graph)
for w in sorted(most_important_link, key=most_important_link.get, reverse = True):
    print(w, most_important_link[w])
# Out:
# CStratton00 0.4112458931393996
# AHarriss155 0.3916469306077529
# James-Fritz 0.31083182003425536
# RCarson10 0.3062744755718859
# jcanode 0.30067310302706235
# pnghi320 0.30008119031279257
# justinfernald 0.2664930236803652
# Jsamyn 0.25899183782964985
# thedinosoar 0.24939466816127903
# Espence308 0.12419136259442384
# LydiaFritz 0.09204040756767728
# isac-artzi 0.09130170094067316
# mxmnci 0.08317040117255411
# noahr1936 0.08056595744593938
# dharmab31 0.05423451778928666
# brandondavid714 0.05423451778928666
# Kevin-Wooden 0.05423451778928666
# rhawks00 0.05423451778928666
# Austin-Chandler 0.05423451778928666
# KyleLuster 0.05423451778928666
# ReuelAbi 0.05423451778928666
# MicahWillis 0.05423451778928666
# JakeHafele101 0.05423451778928666
# drewesch 0.05423451778928666
# carsonbfoley 0.05423451778928666
# Iroe7 0.05423451778928666
# jakewhitebread 0.05164956006321129
# natsukiabe529 0.05164956006321129
# malikbawa 0.05164956006321129
# Luis-1337 0.05164956006321129
# ...

# %%
# find the closeness centrality
best_connector = nx.betweenness_centrality(followers_graph)
for w in sorted(best_connector, key=best_connector.get, reverse = True):
    print(w, best_connector[w])
# Out:
# CStratton00 0.699770258980785
# mxmnci 0.5827067669172932
# AHarriss155 0.21522556390977446
# jcanode 0.12496867167919802
# thedinosoar 0.1114766081871345
# James-Fritz 0.05275689223057643
# RCarson10 0.018776106934001672
# pnghi320 0.018671679197994985
# Jsamyn 0.0034252297410192144
# Espence308 0.0020050125313283203
# justinfernald 0.0004177109440267335
# dharmab31 0.0
# brandondavid714 0.0
# Kevin-Wooden 0.0
# rhawks00 0.0
# Austin-Chandler 0.0
# KyleLuster 0.0
# ReuelAbi 0.0
# MicahWillis 0.0
# JakeHafele101 0.0
# drewesch 0.0
# carsonbfoley 0.0
# Iroe7 0.0
# LydiaFritz 0.0
# hritikb27 0.0
# torvalds 0.0
# mguay22 0.0
# codediodeio 0.0
# streamich 0.0
# bfan1256 0.0
# EmersonDove 0.0
# metachris 0.0
# mattgperry 0.0
# Chalarangelo 0.0
# trekhleb 0.0
# isaacs 0.0
# kentcdodds 0.0
# jossmac 0.0
# crubier 0.0
# mxstbr 0.0
# sct 0.0
# Dulaya 0.0
# geohot 0.0
# timgrossmann 0.0
# noahr1936 0.0
# jakewhitebread 0.0
# natsukiabe529 0.0
# malikbawa 0.0
# Luis-1337 0.0
# isac-artzi 0.0
# ...

# %%
# find subgroups for people that are connected to CStratton00
groupCol = nx.bfs_tree(followers_graph, "CStratton00")
plt.figure(figsize=(20,20))
nx.draw_networkx(groupCol)
plt.show()

# %%
# find subgroups for people that are connected to mxmnci
groupMXM = nx.bfs_tree(followers_graph, "mxmnci")
plt.figure(figsize=(20,20))
nx.draw_networkx(groupMXM)
plt.show()

# %%
# find clustering value for people that are connected to CStratton00
nx.clustering(followers_graph)
# Out:
# {'CStratton00': 0.10476190476190476,
#  'RCarson10': 0.6428571428571429,
#  'dharmab31': 0,
#  'mxmnci': 0,
#  'pnghi320': 0.6428571428571429,
#  'AHarriss155': 0.21666666666666667,
#  'brandondavid714': 0,
#  'James-Fritz': 0.5277777777777778,
#  'Kevin-Wooden': 0,
#  'rhawks00': 0,
#  'Austin-Chandler': 0,
#  'KyleLuster': 0,
#  'jcanode': 0.2727272727272727,
#  'thedinosoar': 0.2777777777777778,
#  'justinfernald': 0.9333333333333333,
#  'ReuelAbi': 0,
#  'MicahWillis': 0,
#  'JakeHafele101': 0,
#  'drewesch': 0,
#  'carsonbfoley': 0,
#  'Iroe7': 0,
#  'Jsamyn': 0.8,
#  'LydiaFritz': 1.0,
#  'hritikb27': 0,
#  'torvalds': 0,
#  'mguay22': 0,
#  'codediodeio': 0,
#  'streamich': 0,
#  'bfan1256': 0,
#  'EmersonDove': 0,
#  'metachris': 0,
#  'mattgperry': 0,
#  'Chalarangelo': 0,
#  'trekhleb': 0,
#  'isaacs': 0,
#  'kentcdodds': 0,
#  'jossmac': 0,
#  'crubier': 0,
#  'mxstbr': 0,
#  'sct': 0,
#  'Dulaya': 0,
#  'geohot': 0,
#  'timgrossmann': 0,
#  'noahr1936': 1.0,
# ...

# %% [markdown]
# ## Conclusion
# Based on the results, the most influential people are CStratton00 and mxmnci. We also found out who the most critical connections are, and the top three are CStratton00, AHarriss155, and James-Fritz. Based on the initial graph, we identified two major clusters and plotted those separately to take a closer look at them. We Plotted CStratton00 and his connections and mxmnci because they were the most influential people in this dataset.

# %% [markdown]
# ## Resources
#
#     https://www.youtube.com/watch?v=NgkMVRGeS1c
