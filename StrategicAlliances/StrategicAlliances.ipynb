# %% [markdown]
# # Strategic Alliances Project
# Dharma Teja Bhattu and Collin Stratton
#
# CST-440
#
# Dr. Isac Artzi
#
# 3/20/2022

# %% [markdown]
# # Introduction
# *intro the project and talk about what will be covered*
# *talk about what the code below does in separate paragraph*

# %%
# import libraries
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# %%
# Read in the data
df = pd.read_csv('FinancialTies.csv', index_col=0)
df.head()
# Out:
#            Microsoft  IBM  Google  Facebook  Apple  Oracle  HP  Fujitsu  \
# Microsoft          0    1       1         1      1       1   1        1
# IBM                1    0       0         1      1       0   0        1
# Google             1    0       0         0      0       0   0        1
# Facebook           1    1       0         0      0       0   0        1
# Apple              1    1       0         0      0       1   1        1
#
#            Xiaomi  Samsung  Siemens  SAP  SAS  Nvidia  Amazon  Checkpoint  \
# Microsoft       1        1        1    1    1       1       1           1
# IBM             0        1        0    0    0       1       1           1
# Google          0        0        1    0    0       0       1           0
# Facebook        0        0        0    0    0       1       1           0
# Apple           0        0        1    0    0       0       1           0
#
#            Hitachi  Dell  GE  Honeywell
# Microsoft        1     1   1          1
# ...

# %%
# create adjacency list
G = nx.from_pandas_adjacency(df)

# plot the adjacency list
plt.figure(figsize=(10,10))
nx.draw(G, with_labels=True)

# %% [markdown]
# # Potential Alliances
# *look at major company connections and speculate alliances, such as Samsung and Amazon with Amazon selling Samsung phones*

# %% [markdown]
# # Impact of Interlocking Boards in Alliances
# *from the noteable alliances, speculate how those companies would operate if they shared directors in their boards*

# %% [markdown]
# # Strategic Opportunities
# *look at the companies that are not in the noteable alliances and speculate on how they could be involved in the strategic alliances*

# %% [markdown]
# # Challenges
# *look for companies that are over-saturated in their field or have too many connections and speculate the challenges they might have*
