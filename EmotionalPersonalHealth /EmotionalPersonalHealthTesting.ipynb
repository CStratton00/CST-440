# %%
# imports
import pandas as pd
import random as rd

# get data
df = pd.read_csv('./ObesityDataSet_raw_and_data_sinthetic.csv', header=0, usecols=['NObeyesdad'])
print(df.head())
# Out:
#             NObeyesdad
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# 4  Overweight_Level_II

# %%
# create empty arrays for the values in the dataset
insufficient_weight = []
normal_weight = []
overweight_level_1 = []
overweight_level_2 = []
obesity_type_1 = []
obesity_type_2 = []
obesity_type_3 = []

# separate the values in the dataset
for row in df.iterrows():
    # print(row[1]['NObeyesdad'])
    if row[1]['NObeyesdad'] == 'Insufficient_Weight':
        insufficient_weight.append(row[0])
    elif row[1]['NObeyesdad'] == 'Normal_Weight':
        normal_weight.append(row[0])
    elif row[1]['NObeyesdad'] == 'Overweight_Level_I':
        overweight_level_1.append(row[0])
    elif row[1]['NObeyesdad'] == 'Overweight_Level_II':
        overweight_level_2.append(row[0])
    elif row[1]['NObeyesdad'] == 'Obesity_Type_I':
        obesity_type_1.append(row[0])
    elif row[1]['NObeyesdad'] == 'Obesity_Type_II':
        obesity_type_2.append(row[0])
    elif row[1]['NObeyesdad'] == 'Obesity_Type_III':
        obesity_type_3.append(row[0])

# print the number of values in each array
print('Insufficient weight:', len(insufficient_weight))
print('Normal weight:', len(normal_weight))
print('Overweight level 1:', len(overweight_level_1))
print('Overweight level 2:', len(overweight_level_2))
print('Obesity type 1:', len(obesity_type_1))
print('Obesity type 2:', len(obesity_type_2))
print('Obesity type 3:', len(obesity_type_3))
# Out:
# Insufficient weight: 272
# Normal weight: 287
# Overweight level 1: 290
# Overweight level 2: 290
# Obesity type 1: 351
# Obesity type 2: 297
# Obesity type 3: 324

# %%
# create list for bipartite graph
connections = []

# create connections between the values in the dataset
for row in df.iterrows():
    # create 5 random numbers with decreasing values
    rd_1 = rd.randint(0, 5)
    rd_2 = rd.randint(0, 4)
    rd_3 = rd.randint(0, 3)
    rd_4 = rd.randint(0, 2)
    rd_5 = rd.randint(0, 1)
    rd_6 = rd.randint(0, 1)
    rd_7 = rd.randint(0, 1)

    add_connection = rd.randint(0, 100)

    if add_connection == 0:
        if row[1]['NObeyesdad'] == 'Insufficient_Weight':
            for val in range(0, rd_1):
                connections.append([row[0], rd.choice(insufficient_weight)])
            for val in range(0, rd_2):
                connections.append([row[0], rd.choice(normal_weight)])
            for val in range(0, rd_3):
                connections.append([row[0], rd.choice(overweight_level_1)])
            for val in range(0, rd_4):
                connections.append([row[0], rd.choice(overweight_level_2)])
            for val in range(0, rd_5):
                connections.append([row[0], rd.choice(obesity_type_1)])
            for val in range(0, rd_6):
                connections.append([row[0], rd.choice(obesity_type_2)])
            for val in range(0, rd_7):
                connections.append([row[0], rd.choice(obesity_type_3)])
        elif row[1]['NObeyesdad'] == 'Normal_Weight':
            for val in range(0, rd_1 + 5):
                connections.append([row[0], rd.choice(normal_weight)])
            for val in range(0, rd_2 + 5):
                connections.append([row[0], rd.choice(insufficient_weight)])
            for val in range(0, rd_3 + 5):
                connections.append([row[0], rd.choice(overweight_level_2)])
            for val in range(0, rd_4 + 5):
                connections.append([row[0], rd.choice(obesity_type_1)])
            for val in range(0, rd_5 + 5):
                connections.append([row[0], rd.choice(obesity_type_2)])
            for val in range(0, rd_6 + 5):
                connections.append([row[0], rd.choice(obesity_type_3)])
            for val in range(0, rd_7 + 5):
                connections.append([row[0], rd.choice(overweight_level_1)])
        elif row[1]['NObeyesdad'] == 'Overweight_Level_I':
            for val in range(0, rd_1):
                connections.append([row[0], rd.choice(overweight_level_1)])
            for val in range(0, rd_2):
                connections.append([row[0], rd.choice(normal_weight)])
            for val in range(0, rd_3):
                connections.append([row[0], rd.choice(insufficient_weight)])
            for val in range(0, rd_4):
                connections.append([row[0], rd.choice(obesity_type_1)])
            for val in range(0, rd_5):
                connections.append([row[0], rd.choice(obesity_type_2)])
            for val in range(0, rd_6):
                connections.append([row[0], rd.choice(obesity_type_3)])
            for val in range(0, rd_7):
                connections.append([row[0], rd.choice(overweight_level_2)])
        elif row[1]['NObeyesdad'] == 'Overweight_Level_II':
            for val in range(0, rd_1):
                connections.append([row[0], rd.choice(overweight_level_2)])
            for val in range(0, rd_2):
                connections.append([row[0], rd.choice(obesity_type_1)])
            for val in range(0, rd_3):
                connections.append([row[0], rd.choice(normal_weight)])
            for val in range(0, rd_4):
                connections.append([row[0], rd.choice(insufficient_weight)])
            for val in range(0, rd_5):
                connections.append([row[0], rd.choice(obesity_type_2)])
            for val in range(0, rd_6):
                connections.append([row[0], rd.choice(obesity_type_3)])
            for val in range(0, rd_7):
                connections.append([row[0], rd.choice(overweight_level_1)])
        elif row[1]['NObeyesdad'] == 'Obesity_Type_I':
            for val in range(0, rd_1):
                connections.append([row[0], rd.choice(obesity_type_1)])
            for val in range(0, rd_2):
                connections.append([row[0], rd.choice(overweight_level_1)])
            for val in range(0, rd_3):
                connections.append([row[0], rd.choice(normal_weight)])
            for val in range(0, rd_4):
                connections.append([row[0], rd.choice(insufficient_weight)])
            for val in range(0, rd_5):
                connections.append([row[0], rd.choice(obesity_type_2)])
            for val in range(0, rd_6):
                connections.append([row[0], rd.choice(obesity_type_3)])
            for val in range(0, rd_7):
                connections.append([row[0], rd.choice(overweight_level_2)])
        elif row[1]['NObeyesdad'] == 'Obesity_Type_II':
            for val in range(0, rd_1):
                connections.append([row[0], rd.choice(obesity_type_2)])
            for val in range(0, rd_2):
                connections.append([row[0], rd.choice(overweight_level_2)])
            for val in range(0, rd_3):
                connections.append([row[0], rd.choice(obesity_type_1)])
            for val in range(0, rd_4):
                connections.append([row[0], rd.choice(normal_weight)])
            for val in range(0, rd_5):
                connections.append([row[0], rd.choice(insufficient_weight)])
            for val in range(0, rd_6):
                connections.append([row[0], rd.choice(obesity_type_3)])
            for val in range(0, rd_7):
                connections.append([row[0], rd.choice(overweight_level_1)])
        elif row[1]['NObeyesdad'] == 'Obesity_Type_III':
            for val in range(0, rd_1):
                connections.append([row[0], rd.choice(obesity_type_3)])
            for val in range(0, rd_2):
                connections.append([row[0], rd.choice(overweight_level_1)])
            for val in range(0, rd_3):
                connections.append([row[0], rd.choice(obesity_type_1)])
            for val in range(0, rd_4):
                connections.append([row[0], rd.choice(normal_weight)])
            for val in range(0, rd_5):
                connections.append([row[0], rd.choice(insufficient_weight)])
            for val in range(0, rd_6):
                connections.append([row[0], rd.choice(obesity_type_2)])
            for val in range(0, rd_7):
                connections.append([row[0], rd.choice(overweight_level_2)])

# %%
labelDict = {}

for i in range(0, len(connections)):
    for j in range(0, len(connections[i])):
        labelDict[connections[i][j]] = df['NObeyesdad'][connections[i][0]]

labelDict
# Out:
# {49: 'Normal_Weight',
#  385: 'Normal_Weight',
#  442: 'Normal_Weight',
#  171: 'Normal_Weight',
#  141: 'Normal_Weight',
#  227: 'Normal_Weight',
#  240: 'Normal_Weight',
#  115: 'Normal_Weight',
#  282: 'Normal_Weight',
#  644: 'Normal_Weight',
#  420: 'Normal_Weight',
#  330: 'Normal_Weight',
#  526: 'Normal_Weight',
#  534: 'Normal_Weight',
#  656: 'Insufficient_Weight',
#  544: 'Normal_Weight',
#  563: 'Normal_Weight',
#  1179: 'Normal_Weight',
#  1094: 'Normal_Weight',
#  1141: 'Normal_Weight',
#  1089: 'Normal_Weight',
#  1118: 'Overweight_Level_II',
#  77: 'Normal_Weight',
#  1168: 'Normal_Weight',
#  1257: 'Normal_Weight',
#  1384: 'Normal_Weight',
#  1279: 'Normal_Weight',
#  1398: 'Obesity_Type_III',
#  1370: 'Normal_Weight',
#  1728: 'Normal_Weight',
#  1666: 'Normal_Weight',
#  1552: 'Normal_Weight',
#  1720: 'Normal_Weight',
#  1615: 'Normal_Weight',
#  1781: 'Normal_Weight',
#  1912: 'Normal_Weight',
#  1950: 'Normal_Weight',
#  1799: 'Normal_Weight',
#  1867: 'Normal_Weight',
#  2041: 'Normal_Weight',
#  506: 'Normal_Weight',
#  902: 'Insufficient_Weight',
#  389: 'Normal_Weight',
#  800: 'Normal_Weight',
#  824: 'Normal_Weight',
#  968: 'Normal_Weight',
#  95: 'Normal_Weight',
#  248: 'Normal_Weight',
#  474: 'Normal_Weight',
#  173: 'Normal_Weight',
#  80: 'Normal_Weight',
#  106: 'Normal_Weight',
#  497: 'Normal_Weight',
#  698: 'Normal_Weight',
#  575: 'Normal_Weight',
#  529: 'Normal_Weight',
#  681: 'Normal_Weight',
#  551: 'Normal_Weight',
#  732: 'Normal_Weight',
#  707: 'Normal_Weight',
#  1030: 'Normal_Weight',
#  1112: 'Normal_Weight',
#  1170: 'Overweight_Level_II',
#  252: 'Normal_Weight',
#  250: 'Normal_Weight',
#  995: 'Normal_Weight',
#  1242: 'Normal_Weight',
#  1295: 'Normal_Weight',
#  1355: 'Normal_Weight',
#  1251: 'Normal_Weight',
#  1437: 'Normal_Weight',
#  165: 'Normal_Weight',
#  90: 'Normal_Weight',
#  1616: 'Normal_Weight',
#  1757: 'Normal_Weight',
#  1537: 'Normal_Weight',
#  1657: 'Normal_Weight',
#  1896: 'Normal_Weight',
#  2010: 'Normal_Weight',
#  2063: 'Normal_Weight',
#  1853: 'Normal_Weight',
#  2089: 'Normal_Weight',
#  899: 'Overweight_Level_I',
#  797: 'Normal_Weight',
#  135: 'Normal_Weight',
#  862: 'Overweight_Level_I',
#  812: 'Obesity_Type_III',
#  890: 'Normal_Weight',
#  149: 'Obesity_Type_I',
#  1374: 'Obesity_Type_I',
#  1429: 'Obesity_Type_I',
#  408: 'Obesity_Type_I',
#  25: 'Insufficient_Weight',
#  579: 'Obesity_Type_I',
#  213: 'Normal_Weight',
#  237: 'Normal_Weight',
#  157: 'Normal_Weight',
#  47: 'Normal_Weight',
#  486: 'Normal_Weight',
#  428: 'Normal_Weight',
#  54: 'Normal_Weight',
#  320: 'Normal_Weight',
#  646: 'Normal_Weight',
#  603: 'Normal_Weight',
#  591: 'Normal_Weight',
#  593: 'Normal_Weight',
#  592: 'Normal_Weight',
#  245: 'Normal_Weight',
#  524: 'Normal_Weight',
#  588: 'Normal_Weight',
#  727: 'Normal_Weight',
#  1146: 'Normal_Weight',
#  4: 'Normal_Weight',
#  1022: 'Normal_Weight',
#  1148: 'Overweight_Level_II',
#  84: 'Normal_Weight',
#  1184: 'Normal_Weight',
#  1099: 'Normal_Weight',
#  1186: 'Overweight_Level_II',
#  1509: 'Normal_Weight',
#  487: 'Normal_Weight',
#  1458: 'Normal_Weight',
#  1368: 'Normal_Weight',
#  1531: 'Normal_Weight',
#  1513: 'Normal_Weight',
#  1785: 'Normal_Weight',
#  229: 'Normal_Weight',
#  1517: 'Obesity_Type_I',
#  1624: 'Normal_Weight',
#  1932: 'Normal_Weight',
#  1802: 'Normal_Weight',
#  1871: 'Normal_Weight',
#  1885: 'Normal_Weight',
#  2057: 'Normal_Weight',
#  1888: 'Normal_Weight',
#  857: 'Overweight_Level_I',
#  798: 'Normal_Weight',
#  362: 'Normal_Weight',
#  826: 'Normal_Weight',
#  168: 'Normal_Weight',
#  261: 'Normal_Weight',
#  256: 'Overweight_Level_II',
#  1497: 'Overweight_Level_II',
#  377: 'Overweight_Level_II',
#  8: 'Overweight_Level_II',
#  337: 'Overweight_Level_II',
#  1539: 'Overweight_Level_II',
#  291: 'Insufficient_Weight',
#  59: 'Insufficient_Weight',
#  101: 'Insufficient_Weight',
#  877: 'Insufficient_Weight',
#  888: 'Insufficient_Weight',
#  1176: 'Overweight_Level_II',
#  1145: 'Insufficient_Weight',
#  1380: 'Insufficient_Weight',
#  1567: 'Insufficient_Weight',
#  653: 'Insufficient_Weight',
#  444: 'Insufficient_Weight',
#  163: 'Obesity_Type_I',
#  460: 'Insufficient_Weight',
#  30: 'Overweight_Level_I',
#  789: 'Insufficient_Weight',
#  1412: 'Insufficient_Weight',
#  1579: 'Insufficient_Weight',
#  808: 'Overweight_Level_I',
#  788: 'Overweight_Level_I',
#  942: 'Overweight_Level_I',
#  939: 'Obesity_Type_I',
#  1817: 'Overweight_Level_I',
#  1190: 'Overweight_Level_I',
#  848: 'Overweight_Level_I',
#  791: 'Overweight_Level_I',
#  760: 'Overweight_Level_I',
#  62: 'Overweight_Level_I',
#  467: 'Overweight_Level_I',
#  298: 'Overweight_Level_I',
#  177: 'Overweight_Level_I',
#  1511: 'Overweight_Level_I',
#  414: 'Overweight_Level_I',
#  1721: 'Overweight_Level_I',
#  2065: 'Overweight_Level_I',
#  889: 'Overweight_Level_I',
#  143: 'Overweight_Level_I',
#  477: 'Overweight_Level_I',
#  182: 'Overweight_Level_I',
#  691: 'Overweight_Level_I',
#  1353: 'Overweight_Level_I',
#  1144: 'Overweight_Level_I',
#  871: 'Overweight_Level_I',
#  811: 'Overweight_Level_I',
#  350: 'Overweight_Level_I',
#  105: 'Overweight_Level_I',
#  126: 'Overweight_Level_I',
#  493: 'Overweight_Level_I',
#  717: 'Overweight_Level_I',
#  680: 'Overweight_Level_I',
#  724: 'Overweight_Level_I',
#  1742: 'Overweight_Level_I',
#  1835: 'Overweight_Level_I',
#  925: 'Overweight_Level_I',
#  658: 'Overweight_Level_I',
#  620: 'Overweight_Level_I',
#  1346: 'Overweight_Level_I',
#  1012: 'Overweight_Level_II',
#  1015: 'Overweight_Level_II',
#  1163: 'Overweight_Level_II',
#  124: 'Overweight_Level_II',
#  14: 'Overweight_Level_II',
#  739: 'Overweight_Level_II',
#  2036: 'Overweight_Level_II',
#  795: 'Overweight_Level_II',
#  1026: 'Overweight_Level_II',
#  1297: 'Overweight_Level_II',
#  1394: 'Overweight_Level_II',
#  1214: 'Overweight_Level_II',
#  1233: 'Obesity_Type_I',
#  112: 'Overweight_Level_II',
#  439: 'Overweight_Level_II',
#  2085: 'Overweight_Level_II',
#  846: 'Overweight_Level_II',
#  1058: 'Overweight_Level_II',
#  251: 'Overweight_Level_II',
#  21: 'Overweight_Level_II',
#  187: 'Overweight_Level_II',
#  471: 'Overweight_Level_II',
#  1243: 'Overweight_Level_II',
#  498: 'Overweight_Level_II',
#  944: 'Overweight_Level_II',
#  1189: 'Overweight_Level_II',
#  1239: 'Obesity_Type_I',
#  387: 'Overweight_Level_II',
#  1220: 'Overweight_Level_II',
#  1229: 'Obesity_Type_I',
#  284: 'Overweight_Level_II',
#  836: 'Overweight_Level_II',
#  1126: 'Overweight_Level_II',
#  1137: 'Overweight_Level_II',
#  1103: 'Overweight_Level_II',
#  33: 'Overweight_Level_II',
#  596: 'Overweight_Level_II',
#  1635: 'Overweight_Level_II',
#  2019: 'Overweight_Level_II',
#  1123: 'Overweight_Level_II',
#  978: 'Overweight_Level_II',
#  1206: 'Overweight_Level_II',
#  1314: 'Overweight_Level_II',
#  108: 'Overweight_Level_II',
#  706: 'Overweight_Level_II',
#  1188: 'Overweight_Level_II',
#  1040: 'Overweight_Level_II',
#  154: 'Obesity_Type_I',
#  1860: 'Overweight_Level_II',
#  1282: 'Obesity_Type_I',
#  1465: 'Obesity_Type_I',
#  1288: 'Obesity_Type_I',
#  923: 'Obesity_Type_I',
#  510: 'Obesity_Type_I',
#  1587: 'Obesity_Type_III',
#  1892: 'Obesity_Type_I',
#  1397: 'Obesity_Type_I',
#  1357: 'Obesity_Type_I',
#  753: 'Obesity_Type_I',
#  775: 'Obesity_Type_I',
#  851: 'Obesity_Type_I',
#  51: 'Obesity_Type_I',
#  172: 'Obesity_Type_I',
#  491: 'Obesity_Type_I',
#  566: 'Obesity_Type_I',
#  988: 'Obesity_Type_I',
#  1417: 'Obesity_Type_I',
#  179: 'Obesity_Type_I',
#  882: 'Obesity_Type_I',
#  955: 'Obesity_Type_I',
#  842: 'Obesity_Type_I',
#  280: 'Obesity_Type_I',
#  24: 'Obesity_Type_I',
#  2005: 'Obesity_Type_I',
#  1431: 'Obesity_Type_I',
#  1461: 'Obesity_Type_I',
#  1311: 'Obesity_Type_I',
#  1434: 'Obesity_Type_I',
#  1345: 'Obesity_Type_I',
#  1435: 'Obesity_Type_I',
#  299: 'Obesity_Type_I',
#  327: 'Obesity_Type_I',
#  885: 'Obesity_Type_I',
#  779: 'Obesity_Type_I',
#  357: 'Obesity_Type_I',
#  422: 'Obesity_Type_I',
#  32: 'Obesity_Type_I',
#  576: 'Obesity_Type_I',
#  1496: 'Obesity_Type_I',
#  1269: 'Obesity_Type_I',
#  419: 'Obesity_Type_I',
#  1481: 'Obesity_Type_I',
#  189: 'Obesity_Type_I',
#  410: 'Obesity_Type_I',
#  1725: 'Obesity_Type_II',
#  1561: 'Obesity_Type_II',
#  1558: 'Obesity_Type_II',
#  1685: 'Obesity_Type_II',
#  1549: 'Obesity_Type_II',
#  1499: 'Obesity_Type_II',
#  285: 'Obesity_Type_II',
#  211: 'Obesity_Type_II',
#  409: 'Obesity_Type_II',
#  1789: 'Obesity_Type_II',
#  1019: 'Obesity_Type_II',
#  1317: 'Obesity_Type_II',
#  1807: 'Obesity_Type_III',
#  2011: 'Obesity_Type_III',
#  1808: 'Obesity_Type_III',
#  1842: 'Obesity_Type_III',
#  2014: 'Obesity_Type_III',
#  1923: 'Obesity_Type_III',
#  297: 'Obesity_Type_III',
#  324: 'Obesity_Type_III',
#  1222: 'Obesity_Type_III',
#  1913: 'Obesity_Type_III',
#  1916: 'Obesity_Type_III',
#  2037: 'Obesity_Type_III',
#  6: 'Obesity_Type_III',
#  140: 'Obesity_Type_III',
#  1585: 'Obesity_Type_III',
#  1074: 'Obesity_Type_III',
#  1931: 'Obesity_Type_III',
#  2078: 'Obesity_Type_III',
#  1930: 'Obesity_Type_III',
#  1801: 'Obesity_Type_III',
#  1803: 'Obesity_Type_III',
#  195: 'Obesity_Type_III',
#  898: 'Obesity_Type_III',
#  792: 'Obesity_Type_III',
#  188: 'Obesity_Type_III',
#  464: 'Obesity_Type_III',
#  664: 'Obesity_Type_III',
#  1607: 'Obesity_Type_III',
#  1063: 'Obesity_Type_III',
#  2074: 'Obesity_Type_III',
#  2039: 'Obesity_Type_III',
#  1964: 'Obesity_Type_III',
#  1837: 'Obesity_Type_III',
#  2018: 'Obesity_Type_III',
#  1247: 'Obesity_Type_III',
#  1256: 'Obesity_Type_III',
#  247: 'Obesity_Type_III',
#  56: 'Obesity_Type_III',
#  1011: 'Obesity_Type_III'}

# %%
import networkx as nx
import matplotlib.pyplot as plt

# create graph from connections
G = nx.Graph()
G.add_edges_from(connections)

plt.figure(figsize=(20,20))

# draw graph
nx.draw(G, labels=labelDict, with_labels=True)

# %%
# write connection data to file
with open('ObesityDataSet.csv', 'w') as f:
    for item in connections:
        f.write("%s,%s\n" % (item[0], item[1]))
